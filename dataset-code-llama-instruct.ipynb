# %% [markdown]
# Loads the CSV in corpus and format for code Llama Instruct

# %%
from neowGen import datasetGenerator

dg = datasetGenerator("code llama instruct")
#we add a context to each line in order to specify we're working in Cairo
dg.setlocalContext("In Cairo: ")
dg.generate_from_corpus("corpus_src")
dg.generate_dataset(verbose=True)
#dg.save_to_disk("corpus")
# Out:
# Processing subdirectories: 100%|██████████| 2/2 [00:00<00:00, 123.02it/s]
# Error reading corpus_src/train/options.csv: Error tokenizing data. C error: Expected 2 fields in line 19, saw 3
#
# Error reading corpus_src/train/address.csv: Error tokenizing data. C error: EOF inside string starting at row 11
# Number of dataframes created: 2
# Number of CSV files read for 'eval' dataframe: 1
# Number of CSV files read for 'train' dataframe: 26
# Generating prompt for dataset 'eval':
# in cairo write a if statement, that tests if c is equal to 3. If yes, return 1
# in Cairo, define a function named fofo that accepts a felt a as parameter in cairo
# write a sequence of cairo code that matches 0 to 3, 1 to 4 and any other value to 5
# In Cairo, write an enumeration with Rouge, Vert, Bleu
# In Cairo, Write a function that returns the Vert value from an enum
# Generating prompt for dataset 'train':
# What are dictionaries
# what are dictionaries used for ?
# Can I use any type for keys of a dictionary ?
# define a dictionary called messages
# create a dictionary and insert value 100 associated to key 'Alex' and 200 to key 'maria'
# create a dictionary, add a value associated to key 200, and read the value associated to key 200
# what value will I get in x:
#     let mut dict: Felt252Dict<u64> = Default::default();
#
#     dict.insert('Alex', 100);
#     dict.insert('Maria', 200);
#
# x= let value_read = dict.get('Bob');
#
# Can I delete an element from a dictionary
#  "what is ownership in Cairo ?"
# add a value of 0 to an array named myArray
# Create an array and add three values to it
# Create an array of u128
# Create an array of u32
# Create an array of u64
# create an array, add 3 values, and remove one
#  "How can I get the value at a specific index of an array"
# create an arary, add 2 values, affect the first value to a variable
# get the size of the array 'myArray'
# test if myArray is empty
# create an array 'messages' that contains a u128, a felt252, a u32
# create an array 'messages' that contains a u64, a u16, a tuple (u32,u32)
# What is a span
# what are spans used for ?
# Create a span out of an array 'array'
# what is wrong with this code: arr[index]
# why is this code incorrect: myArray.pop()
# Can I push values to an array
# how can I get the size of an array in Cairo
# How do I know if an array is empty
# Create an array, append two values and print them
# myArray is empty, what does that code do: myArray.pop_front();
# in cairo, write a function named 'foo' that takes a felt parameter
# in cairo write a function named Add that returns 3+5
# in cairo, define a function named toto in cairo
# in cairo, define a function named toto in cairo that returns 4
# in cairo, define a function that returns its felt parameter Y
# in cairo, define a function that returns the difference of its parameters X and Y
# in cairo, define a function named toto in cairo that takes a parameter f. f is a felt
# in cairo, define a function toto that returns a felt of value 0
# in cairo, define a function named toto that accepts a felt a as parameter, and returns a felt of value 0
# in cairo, define a function named toto that accepts a felt a as parameter
# is this program working in Cairo ?
# use debug::PrintTrait;
#
# fn main() {
#     let x: u64 = 2;
#     x.print();
#     let x: felt252 = x.into(); // converts x to a felt, type annotation is required.
#     x.print()
# }
# how do I declare a view function
# what can view function do and can not do
# What is an external function
# write an external function
# in cairo write a if statement, that tests if a is equal to 0. If yes, returns 1
# set a to 5 if b=1 otherwise a to 6
# in cairo, write a hello world
# In cairo, Is this program working fine ?
# use debug::PrintTrait;
# fn main() {
#     let x = 5;
#     x.print();
#     x = 6;
#     x.print();
# }
# In cairo, what error will this program generate ?
# use debug::PrintTrait;
# fn main() {
#     let x = 5;
#     x.print();
#     x = 6;
#     x.print();
# }
# error: Cannot assign to an immutable variable.
# In cairo, a felt is a type of variable
# is this program working in Cairo ?
# use debug::PrintTrait;
#
# fn main() {
#     let mut x: u64 = 2;
#     x.print();
#     x = 100_felt252;
#     x.print()
# }
# Do I need to specify types for variables in Cairo ?
# in Cairo, declare a felt252 of value 3
# in Cairo, declare a mut felt252 of value 31
# in Cairo, declare a mutable felt252 of value 72
# in Cairo, declare a u32  of value 3
# in Cairo, declare a mut u32  of value 31
# in Cairo, declare a mutable u32  of value 72
# what are scalar types in Cairo ?
# Is there a default type in cairo?
# What is the default type in Cairo
# what is a field element in Cairo ?
# Can overflow happens in Cairo ?
# What is the difference between an int and a field element in Cairo?
# Should I use int or field elements in Cairo ?
# Why should i prefer int to field in Cairo ?
# can an int be negative in cairo ?
# what is the size of u8 in Cairo ?
# what is the size of u16 in Cairo ?
# what is the size of u32 in Cairo ?
# what is the size of u64 in Cairo ?
# what is the size of u128 in Cairo ?
# what is the size of u256 in Cairo ?
# what is the size of usize in Cairo ?
# what is u8 in Cairo ?
# what is u32 in Cairo ?
# what is u64 in Cairo ?
# what is u128 in Cairo ?
# what is u16 in Cairo ?
# what is u256 in Cairo ?
# is this program working in Cairo ?
# fn sub_u8s(x: u8, y: u8) -> u8 {
#     x - y
# }
#
# fn main() {
#     sub_u8s(1, 3);
# }
# affect the sum of 5 and 8 to a u128
# affect the subtraction of 95 and 4 to a u128
# affect the product of 4 and 30 to a u128
# Affect the division quotient of 56 by 32 to a u128
# Affect the division quotient of 64 by 32 to a u128
# Affect the division remainder  of 43 by 5 to a u128
# What operation does Cairo supports on int ?
# Does Cairo have bool ?
# Define t as a boolean with value true
# define a bool f with explicit type, and set it to false
# Does cairo supports strings
# define a short_string as char c
# affect a variable to 'hello world'
# What is a tuple ?
# How do I create a tuple ?
# write a tuple for a u32,u64 and a bool
# write a tuple for a u16, felt252 and a bool
# how do I get the values from a tuple ?
# get (x,y,z) from tup
# write a program that defines a tuple, get the values (x,y,z) from it and print a message if y is equal to 6
# Can I declare a tuple with value and types at the same time ?
# What is a unit type ?
# How do you define a function in Cairo ?
# what are function parameters or arguments ?
# Do I need to specify parameters type for a function ?
# What is wrong with the declaration of this function:
#     fn toto(a){
#     }
#
# What are named parameters ?
# give an example of named parameters
# Write a function that accepts 2 argmuents a and b
# explain this code:
#     let y = {
#         let x = 3;
#         x + 1;
#     };
#
# division in Cairo ?
# add 1 to i
# in Cairo,define an enumeration with Red, Green, Blue
# in Cairo, define an enumeration with A, B, C
# in Cairo,define a function that returns the Green value from an enum
# create an enumeration in cairo for some nationality
# create an enumeration in cairo for some planets
# create an enumeration in cairo for some names
# create an enumeration in cairo for some units
# how can I cast a variable to another type
# What does the 'try_into' method do ?
# what does the 'into' method do ?
# how does into and try_into work ?
# Cast a u64 into a u128
# cast a felt252 into a u256
# Cast a felt252 into a usize, which is a smaller size
# cast a felt252 into a u8
# cast a u8 into a u16
# cast a u16 into a u32
# cast a u32 into a u64
# cast a u64 into a u128
# cast a u16 into a felt252
# declare a felt and print it
# How can I debug
# Cairo code uses snake case as the conventional style for function and variable names, in which all letters are lowercase and underscores separate words.
#
# You can use the keyword assert.
#
# The syntax is: assert(condition,'condition not met'
#
#
#     assert(x == 0, 'Balance is not 0 ');
#
# Explanation:
# - These line of code will assert if x is different from 0
#
#
#     {                      // s is not valid here, it’s not yet declared
#         let s = 'hello';   // s is valid from this point forward
#
#         // do stuff with s
#     }
#     // s is not valid here
#
# Explanations:
# - When s comes into scope, it is valid.
# - It remains valid until it goes out of scope.
#
#
#     #[derive(Copy, Drop)]
#     struct Rectangle {
#         height: u64,
#         width: u64,
#     }
#
#     fn foo(ref rec: Rectangle)
#     {
#     }
#
# Explanations:
# - In Cairo, a parameter can be passed as mutable reference using the ref modifier.
#
#
# use debug::PrintTrait;
# #[derive(Copy, Drop)]
# struct Rectangle {
#     height: u64,
#     width: u64,
# }
#
# fn main() {
#     let mut rec = Rectangle { height: 3, width: 10 };
#     flip(ref rec);
#     rec.height.print();
#     rec.width.print();
# }
#
# fn flip(ref rec: Rectangle) {
#     let temp = rec.height;
#     rec.height = rec.width;
#     rec.width = temp;
# }
#
# Explanation:
# -First, we change rec to be mut. Then we pass a mutable reference of rec into flip with ref rec, and update the function signature to accept a mutable reference with ref rec: Rectangle. This makes it very clear that the flip function will mutate the value of the Rectangle instance passed as parameter.
#
# The output of the program is:
#
# [DEBUG]
#                                 (raw: 10)
# [DEBUG]	                        (raw: 3)
# As expected, the height and width fields of the rec variable have been swapped.
#
# Cairo is the programming language for smart contracts on Starknet, the Ethereum ZK-Rollup expansion solution. It is also used for writing provable programs.
# With Cairo, we can write provable code. In the context of Starknet, this allows proving the correctness of computations from one state to another.
#
# Unlike most (if not all) of Starknet's competitors that chose to use the EVM (either as-is or adapted) as a base layer, Starknet employs its own VM. This frees developers from the constraints of the EVM, opening up a broader range of possibilities. Coupled with decreased transaction costs, the combination of Starknet and Cairo creates an exciting playground for developers. Native account abstraction enables more complex logic for accounts, that we call 'Smart Accounts', and transaction flows. Emerging use cases include transparent AI and machine learning applications. Finally, blockchain games can be developed entirely on-chain. Starknet has been specifically designed to maximize the capabilities of STARK proofs for optimal scalability.
# How can I declare a variable in cairo ?
# in cairo, How can I declare a variable that can be modified?
# in cairo, let a=5; a=2; Why does this produce an error ?
# can I modify a variable X
# this code produces an error, please adapt the code: let X=2; X=5;
# in cairo, how do I create a mutable variable in cairo ?
# how do I affect a variable ?
# In cairo, define a variable X, add 3 and 4 into x
# In cairo, define a felt variable X as a felt and assign 3
# In Cairo, define a mutable felt X and initialize it to y
# Can I update any variable in cairo ?
# In cairo, Can I change the value of an immutable variable ?
# In cairo, how can I make a variable mutable ?
# can you correct the program: fn main() {
#     let x = 5;
#     x.print();
#     x = 6;
#     x.print();
# }
# what exactly happens when a variable is declared as mut in cairo
# What is a constant in cairo
# What is variable shadowing
# describe what happens to the variable x in this cairo program:
#  let x = 5;
#     let x = x + 1;
#     {
#         let x = x * 2;
#         'Inner scope x value is:'.print();
#         x.print()
#     }
#     'Outer scope x value is:'.print();
#     x.print();
# is shadowing equivalent to mut in cairo ?
# What is the difference between Cairo programs and Starknet contracts?
# What is a starknet contract
# in cairo, what does this line do: use debug::PrintTrait;
# in cairo, what does this line do ? 'Hello, World!'.print();
#
# Why does this progam makes an error ?
#
# use debug::PrintTrait;
#
# struct Rectangle {
#     width: u64,
#     height: u64,
# }
#
# fn main() {
#     let rectangle = Rectangle { width: 30, height: 10, };
#     rectangle.print();
# }
# print 'hello world' ten times
# do a for, for i=0 to 5
# is there a 'for' keyword?
# u(n) = n + u(n-1), please compute u(10)
#  what happens if I call a loop without break
# What mechanism protects from infinite loops ?
# What does this program do ?
#
# fn main() {
#     let mut counter = 0;
#
#     let result = loop {
#         if counter == 10 {
#             break counter * 2;
#         }
#         counter += 1;
#     };
#
#     'The result is '.print();
#     result.print();
# }
# How do I get the caller address
# write a sequence of cairo code that matches 0 to 0, 1 to 2 and any other value to 1
# What are the rules that apply to ownership ?
# what will this code produce ?
#
# fn foo(arr: Array<u128>) {}
#
# fn bar(arr: Array<u128>) {}
#
# fn main() {
#     let mut arr = ArrayTrait::<u128>::new();
#     foo(arr);
#     bar(arr);
# }
#
# How can I avoid moving the ownership of a value to move to a function called with the value as parameter ?
# what does the Drop trait do ?
# How do I add the drop trait to my structure
# implement the Drop trait on my struct Point:
# struct Point {
#     x: u128,
#     y: u128,
# }
# implement ownership on my struct Point:
# struct Point {
#     x: u128,
#     y: u128,
# }
# Why is this code not working:
#
# struct A {}
#
# fn main() {
#     A {}; // error: Value not dropped.
# }
#
# Can I add #[derive(Drop)] to any value ?
# is the value of a variable that goes out of scope is dropped ?
# What is a snapshot?
# create an array, and take a snapshot of it
# Create a function that calulates the length of an array, taking a snapshot as argument
# Give an example of how to use snapshot instead or moving ownership
# what is a desnap
# what is the keyword for desnap ?
# Give an example of desnap
# what are mutable references
# how can I develop in Cairo
# How do I install Scarb
# How do I compile a contract
# how do I create a new project with scarb
# How can I use Remix
# Declare an interface
# What is a contract interface
# define the main entry point of a cairo contract program
# in cairo, what does this code do ? fn main() {
#
# }
# how do I define a struct
# create a struct for a user account
# how do I use a defined struct ?
# Create a struct for representing time
# How can I access a specific field of a struct ?
# define a struct for an email account gerard with password 1234 and then change password to 'toto'
#
# Please simplify that code:
#
# struct User {
#     active: bool,
#     username: felt252,
#     email: felt252,
#     sign_in_count: u64,
# }
#
# fn build_user(email: felt252, username: felt252) -> User {
#     User { active: true, username: username, email: email, sign_in_count: 1, }
# }
#
#
# where are storage variables stored
# is there a way to save a contract state
# How many storage structure can I define
# declare three storage variables
# How do I set a state in storage
# How do I set a state in storage
# how do I create a comment ?
# In cairo, what is the difference between a constant and an immutable variable
# In cairo, how should I write a constant name
# In cairo, declare a constant named toto
# In cairo, declare a constant named Paul
# In cairo, declare a constant named i_love_cairo
# In cairo, declare a constant named aBaB_cDe
# In cairo, What is the scope of a constant
# In cairo, why are constants useful
# What is a constructor
# Give an exemple of a contract with a constructor

# %% [markdown]
# ONLY if you want to push to HFace

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
dg.push_to_hub("pechaut/cairo-instruct")
# Out:
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# ->Dataset 'eval' pushed to hub pechaut/cairo-instruct
# Pushing dataset shards to the dataset hub:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# ->Dataset 'train' pushed to hub pechaut/cairo-instruct
