# %%
import os
import re
from pathlib import Path
import openai
from llama_index import ServiceContext
from llama_index.llms import OpenAI
from llama_index import VectorStoreIndex
from pathlib import Path
from llama_index import Document

# %%
os.environ["OPENAI_API_KEY"] = "sk-111111111111111111111111111111111111111111111111"
os.environ["OPENAI_API_BASE"] = "http://localhost:1234/v1"
openai.api_key = os.environ["OPENAI_API_KEY"]
openai.api_base = os.environ["OPENAI_API_BASE"]

# %%
docs = []
cleaned_text = []
doc_text_cleaned = []
docs_raw = []


with open('output/test.txt', 'r') as docs0:
    doc_text = docs0.read()
 
metadata = {"file_name": "Test.pdf"}
docs = [Document(text=doc_text, metadata=metadata)]

# %%
from llama_index.callbacks import CallbackManager

callback_manager = CallbackManager([])
 
model = OpenAI(model="gpt-3.5-turbo", temperature=0.9),
 
service_context = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.9),
    callback_manager=callback_manager,embed_model='local'
)
 
service_context_large = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.9),
    callback_manager=callback_manager,embed_model='local'
)

# %%
from llama_index.node_parser import SimpleNodeParser
import tiktoken

node_parser = SimpleNodeParser.from_defaults(separator="\n\n",
  chunk_size=512,
  chunk_overlap=0,
  paragraph_separator="\n\n\n",
  secondary_chunking_regex="[^,.;。]+[,.;。]?",
  tokenizer=tiktoken.encoding_for_model("gpt-3.5-turbo").encode)
nodes = node_parser.get_nodes_from_documents(docs)
 
num_questions_per_chunk = 20
question_gen_query = (
    "You are a Teacher/ Professor. Your task is to setup "
    "a quiz/examination. Using the provided context, "
    f"formulate {num_questions_per_chunk} that captures an important fact from the "
    "context. \n"
    "You MUST obey the following criteria:\n"
    "- Restrict the question to the context information provided.\n"
    "- Do NOT create a question that cannot be answered from the context.\n"
    "- Phrase the question so that it does NOT refer to specific context. "
    'For instance, do NOT put phrases like "given provided context" or "in this work" in the question, '
    "because if the question is asked elsewhere it wouldn't be provided specific context. Replace these terms "
    "with specific details.\n"
    "BAD questions:\n"
    "What did the author do in his childhood\n"
    "What were the main findings in this report\n\n"
    "GOOD questions:\n"
    "What did Barack Obama do in his childhood\n"
    "What were the main findings in the original Transformers paper by Vaswani et al.\n\n"
    "Generate the questions below:\n"
)

# %%
from llama_index.evaluation import DatasetGenerator
from llama_index.indices.list import SummaryIndex
fp = open("output//qa_pairs.json", "w")
for idx, node in enumerate(nodes):
    print (node.text)
 
    dataset_generator = DatasetGenerator(
        [node],
        question_gen_query=question_gen_query,
        service_context=service_context,
        metadata_mode="all",
    )
 
    node_questions_0 = await dataset_generator.agenerate_questions_from_nodes(num=20)
    print(f"[Node {idx}] Generated questions:\n {node_questions_0}")
    # for each question, get a response
    for question in node_questions_0:
        index = SummaryIndex([node], service_context=service_context)
        query_engine = index.as_query_engine()
        response = query_engine.query(question)
        out_dict = {"query": question, "response": str(response)}
        print(f"[Node {idx}] Outputs: {out_dict}")
        fp.write(json.dumps(out_dict) + "\n")
 
fp.close()
# Out:
# The Cairo Programming Language
#
# Installation
# Cairo can be installed by simply downloading Scarb. Scarb bundles the Cairo compiler and the Cairo language server together in an easy-to-install package so that you can start writing Cairo code right away.
#
# Scarb is also Cairo's package manager and is heavily inspired by Cargo, Rust’s build system and package manager.
#
# Scarb handles a lot of tasks for you, such as building your code (either pure Cairo or Starknet contracts), downloading the libraries your code depends on, building those libraries, and provides LSP support for the VSCode Cairo 1 extension.
#
# As you write more complex Cairo programs, you might add dependencies, and if you start a project using Scarb, managing external code and dependencies will be a lot easier to do.
#
# Let's start by installing Scarb.
#
# Installing Scarb
# Requirements
# Scarb requires a Git executable to be available in the PATH environment variable.
#
# Installation
# To install Scarb, please refer to the installation instructions. We strongly recommend that you install Scarb via asdf, a CLI tool that can manage multiple language runtime versions on a per-project basis. This will ensure that the version of Scarb you use to work on a project always matches the one defined in the project settings, avoiding problems lead to version mismatch. Otherwise, you can simply run the following command in your terminal, and follow the onscreen instructions. This will install the latest stable release of Scarb.
#
# curl --proto '=https' --tlsv1.2 -sSf https://docs.swmansion.com/scarb/install.sh | sh
# Verify installation by running the following command in new terminal session, it should print both Scarb and Cairo language versions, e.g:
# $ scarb --version
# scarb 2.4.0 (cba988e68 2023-12-06)
# cairo: 2.4.0 (https://crates.io/crates/cairo-lang-compiler/2.4.0)
# sierra: 1.4.0
#
# Installing the VSCode extension
# Cairo has a VSCode extension that provides syntax highlighting, code completion, and other useful features. You can install it from the VSCode Marketplace. Once installed, go into the extension settings, and make sure to tick the Enable Language Server and Enable Scarb options.
# /tmp/ipykernel_1800194/1944346688.py:7: DeprecationWarning: Call to deprecated class DatasetGenerator. (Deprecated in favor of `RagDatasetGenerator` which should be used instead.)
#   dataset_generator = DatasetGenerator(
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:142, in AsyncHTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 await self._send_event(event, timeout=timeout)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:92, in AsyncHTTP11Connection.handle_async_request(self, request)
#      89 async with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     await self._send_request_headers(**kwargs)
#      93 async with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:141, in AsyncHTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1423, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1422 try:
# -> 1423     response = await self._client.send(
#    1424         request,
#    1425         stream=stream or self._should_stream_response_body(request=request),
#    1426         **kwargs,
#    1427     )
#    1428 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:370, in AsyncHTTPTransport.handle_async_request(self, request)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
# --> 370 with map_httpcore_exceptions():
#     371     resp = await self._pool.handle_async_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:142, in AsyncHTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 await self._send_event(event, timeout=timeout)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:92, in AsyncHTTP11Connection.handle_async_request(self, request)
#      89 async with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     await self._send_request_headers(**kwargs)
#      93 async with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:141, in AsyncHTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1423, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1422 try:
# -> 1423     response = await self._client.send(
#    1424         request,
#    1425         stream=stream or self._should_stream_response_body(request=request),
#    1426         **kwargs,
#    1427     )
#    1428 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:370, in AsyncHTTPTransport.handle_async_request(self, request)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
# --> 370 with map_httpcore_exceptions():
#     371     resp = await self._pool.handle_async_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:142, in AsyncHTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 await self._send_event(event, timeout=timeout)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:92, in AsyncHTTP11Connection.handle_async_request(self, request)
#      89 async with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     await self._send_request_headers(**kwargs)
#      93 async with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:141, in AsyncHTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1423, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1422 try:
# -> 1423     response = await self._client.send(
#    1424         request,
#    1425         stream=stream or self._should_stream_response_body(request=request),
#    1426         **kwargs,
#    1427     )
#    1428 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:370, in AsyncHTTPTransport.handle_async_request(self, request)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
# --> 370 with map_httpcore_exceptions():
#     371     resp = await self._pool.handle_async_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# During handling of the above exception, another exception occurred:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:142, in AsyncHTTP11Connection._send_request_headers(self, request)
#     141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#     147 await self._send_event(event, timeout=timeout)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_events.py:96, in Request.__init__(self, method, headers, target, http_version, _parsed)
#      94 else:
#      95     object.__setattr__(
# ---> 96         self, "headers", normalize_and_validate(headers, _parsed=_parsed)
#      97     )
#      98 if not _parsed:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_headers.py:164, in normalize_and_validate(headers, _parsed)
#     163     validate(_field_name_re, name, "Illegal header name {!r}", name)
# --> 164     validate(_field_value_re, value, "Illegal header value {!r}", value)
#     165 assert isinstance(name, bytes)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/h11/_util.py:91, in validate(regex, data, msg, *format_args)
#      90         msg = msg.format(*format_args)
# ---> 91     raise LocalProtocolError(msg)
#      92 return match.groupdict()
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:371, in AsyncHTTPTransport.handle_async_request(self, request)
#     370 with map_httpcore_exceptions():
# --> 371     resp = await self._pool.handle_async_request(req)
#     373 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:92, in AsyncHTTP11Connection.handle_async_request(self, request)
#      89 async with Trace(
#      90     "send_request_headers", logger, request, kwargs
#      91 ) as trace:
# ---> 92     await self._send_request_headers(**kwargs)
#      93 async with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_async/http11.py:141, in AsyncHTTP11Connection._send_request_headers(self, request)
#     139 timeout = timeouts.get("write", None)
# --> 141 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
#     142     event = h11.Request(
#     143         method=request.method,
#     144         target=request.url.target,
#     145         headers=request.headers,
#     146     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1423, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1422 try:
# -> 1423     response = await self._client.send(
#    1424         request,
#    1425         stream=stream or self._should_stream_response_body(request=request),
#    1426         **kwargs,
#    1427     )
#    1428 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1646, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1644 auth = self._build_request_auth(request, auth)
# -> 1646 response = await self._send_handling_auth(
#    1647     request,
#    1648     auth=auth,
#    1649     follow_redirects=follow_redirects,
#    1650     history=[],
#    1651 )
#    1652 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1674, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1673 while True:
# -> 1674     response = await self._send_handling_redirects(
#    1675         request,
#    1676         follow_redirects=follow_redirects,
#    1677         history=history,
#    1678     )
#    1679     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1711, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1709     await hook(request)
# -> 1711 response = await self._send_single_request(request)
#    1712 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1748, in AsyncClient._send_single_request(self, request)
#    1747 with request_context(request=request):
# -> 1748     response = await transport.handle_async_request(request)
#    1750 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:370, in AsyncHTTPTransport.handle_async_request(self, request)
#     358 req = httpcore.Request(
#     359     method=request.method,
#     360     url=httpcore.URL(
#    (...)
#     368     extensions=request.extensions,
#     369 )
# --> 370 with map_httpcore_exceptions():
#     371     resp = await self._pool.handle_async_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[7], line 14
#       5 print (node.text)
#       7 dataset_generator = DatasetGenerator(
#       8     [node],
#       9     question_gen_query=question_gen_query,
#      10     service_context=service_context,
#      11     metadata_mode="all",
#      12 )
# ---> 14 node_questions_0 = await dataset_generator.agenerate_questions_from_nodes(num=20)
#      15 print(f"[Node {idx}] Generated questions:\n {node_questions_0}")
#      16 # for each question, get a response
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/evaluation/dataset_generation.py:283, in DatasetGenerator.agenerate_questions_from_nodes(self, num)
#     281 async def agenerate_questions_from_nodes(self, num: int | None = None) -> List[str]:
#     282     """Generates questions for each document."""
# --> 283     dataset = await self._agenerate_dataset(
#     284         self.nodes, num=num, generate_response=False
#     285     )
#     286     return dataset.questions
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/evaluation/dataset_generation.py:237, in DatasetGenerator._agenerate_dataset(self, nodes, num, generate_response)
#     234     query_tasks.append(task)
#     235     summary_indices.append(index)
# --> 237 responses = await async_module.gather(*query_tasks)
#     238 for idx, response in enumerate(responses):
#     239     result = str(response).strip().split("\n")
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/core/base_query_engine.py:46, in BaseQueryEngine.aquery(self, str_or_query_bundle)
#      44 if isinstance(str_or_query_bundle, str):
#      45     str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 46 return await self._aquery(str_or_query_bundle)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/query_engine/retriever_query_engine.py:188, in RetrieverQueryEngine._aquery(self, query_bundle)
#     183 with self.callback_manager.event(
#     184     CBEventType.QUERY, payload={EventPayload.QUERY_STR: query_bundle.query_str}
#     185 ) as query_event:
#     186     nodes = await self.aretrieve(query_bundle)
# --> 188     response = await self._response_synthesizer.asynthesize(
#     189         query=query_bundle,
#     190         nodes=nodes,
#     191     )
#     193     query_event.on_end(payload={EventPayload.RESPONSE: response})
#     195 return response
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/response_synthesizers/base.py:201, in BaseSynthesizer.asynthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     196     query = QueryBundle(query_str=query)
#     198 with self._callback_manager.event(
#     199     CBEventType.SYNTHESIZE, payload={EventPayload.QUERY_STR: query.query_str}
#     200 ) as event:
# --> 201     response_str = await self.aget_response(
#     202         query_str=query.query_str,
#     203         text_chunks=[
#     204             n.node.get_content(metadata_mode=MetadataMode.LLM) for n in nodes
#     205         ],
#     206         **response_kwargs,
#     207     )
#     209     additional_source_nodes = additional_source_nodes or []
#     210     source_nodes = list(nodes) + list(additional_source_nodes)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/response_synthesizers/compact_and_refine.py:19, in CompactAndRefine.aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      11 async def aget_response(
#      12     self,
#      13     query_str: str,
#    (...)
#      16     **response_kwargs: Any,
#      17 ) -> RESPONSE_TEXT_TYPE:
#      18     compact_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 19     return await super().aget_response(
#      20         query_str=query_str,
#      21         text_chunks=compact_texts,
#      22         prev_response=prev_response,
#      23         **response_kwargs,
#      24     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/response_synthesizers/refine.py:325, in Refine.aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     321 for text_chunk in text_chunks:
#     322     if prev_response is None:
#     323         # if this is the first chunk, and text chunk already
#     324         # is an answer, then return it
# --> 325         response = await self._agive_response_single(
#     326             query_str, text_chunk, **response_kwargs
#     327         )
#     328     else:
#     329         response = await self._arefine_response_single(
#     330             prev_response, query_str, text_chunk, **response_kwargs
#     331         )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/response_synthesizers/refine.py:430, in Refine._agive_response_single(self, query_str, text_chunk, **response_kwargs)
#     428 if response is None and not self._streaming:
#     429     try:
# --> 430         structured_response = await program.acall(
#     431             context_str=cur_text_chunk,
#     432             **response_kwargs,
#     433         )
#     434         structured_response = cast(
#     435             StructuredRefineResponse, structured_response
#     436         )
#     437         query_satisfied = structured_response.query_satisfied
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/response_synthesizers/refine.py:79, in DefaultRefineProgram.acall(self, *args, **kwds)
#      77     answer = answer.json()
#      78 else:
# ---> 79     answer = await self._llm.apredict(
#      80         self._prompt,
#      81         **kwds,
#      82     )
#      83 return StructuredRefineResponse(answer=answer, query_satisfied=True)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/llms/llm.py:280, in LLM.apredict(self, prompt, **prompt_args)
#     278 if self.metadata.is_chat_model:
#     279     messages = self._get_messages(prompt, **prompt_args)
# --> 280     chat_response = await self.achat(messages)
#     281     output = chat_response.message.content or ""
#     282 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/llms/base.py:57, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_async_llm_chat(_self, messages, **kwargs)
#      47 with wrapper_logic(_self) as callback_manager:
#      48     event_id = callback_manager.on_event_start(
#      49         CBEventType.LLM,
#      50         payload={
#    (...)
#      54         },
#      55     )
# ---> 57     f_return_val = await f(_self, messages, **kwargs)
#      58     if isinstance(f_return_val, AsyncGenerator):
#      59         # intercept the generator and add a callback to the end
#      60         async def wrapped_gen() -> ChatResponseAsyncGen:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/llms/openai.py:494, in OpenAI.achat(self, messages, **kwargs)
#     492 else:
#     493     achat_fn = acompletion_to_chat_decorator(self._acomplete)
# --> 494 return await achat_fn(messages, **kwargs)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/llama_index/llms/openai.py:538, in OpenAI._achat(self, messages, **kwargs)
#     536 aclient = self._get_aclient()
#     537 message_dicts = to_openai_message_dicts(messages)
# --> 538 response = await aclient.chat.completions.create(
#     539     messages=message_dicts, stream=False, **self._get_model_kwargs(**kwargs)
#     540 )
#     541 message_dict = response.choices[0].message
#     542 message = from_openai_message(message_dict)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/resources/chat/completions.py:1300, in AsyncCompletions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1251 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1252 async def create(
#    1253     self,
#    (...)
#    1298     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1299 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
# -> 1300     return await self._post(
#    1301         "/chat/completions",
#    1302         body=maybe_transform(
#    1303             {
#    1304                 "messages": messages,
#    1305                 "model": model,
#    1306                 "frequency_penalty": frequency_penalty,
#    1307                 "function_call": function_call,
#    1308                 "functions": functions,
#    1309                 "logit_bias": logit_bias,
#    1310                 "logprobs": logprobs,
#    1311                 "max_tokens": max_tokens,
#    1312                 "n": n,
#    1313                 "presence_penalty": presence_penalty,
#    1314                 "response_format": response_format,
#    1315                 "seed": seed,
#    1316                 "stop": stop,
#    1317                 "stream": stream,
#    1318                 "temperature": temperature,
#    1319                 "tool_choice": tool_choice,
#    1320                 "tools": tools,
#    1321                 "top_logprobs": top_logprobs,
#    1322                 "top_p": top_p,
#    1323                 "user": user,
#    1324             },
#    1325             completion_create_params.CompletionCreateParams,
#    1326         ),
#    1327         options=make_request_options(
#    1328             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1329         ),
#    1330         cast_to=ChatCompletion,
#    1331         stream=stream or False,
#    1332         stream_cls=AsyncStream[ChatCompletionChunk],
#    1333     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1691, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1677 async def post(
#    1678     self,
#    1679     path: str,
#    (...)
#    1686     stream_cls: type[_AsyncStreamT] | None = None,
#    1687 ) -> ResponseT | _AsyncStreamT:
#    1688     opts = FinalRequestOptions.construct(
#    1689         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1690     )
# -> 1691     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1394, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1385 async def request(
#    1386     self,
#    1387     cast_to: Type[ResponseT],
#    (...)
#    1392     remaining_retries: Optional[int] = None,
#    1393 ) -> ResponseT | _AsyncStreamT:
# -> 1394     return await self._request(
#    1395         cast_to=cast_to,
#    1396         options=options,
#    1397         stream=stream,
#    1398         stream_cls=stream_cls,
#    1399         remaining_retries=remaining_retries,
#    1400     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1447, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1444 log.debug("Encountered Exception", exc_info=True)
#    1446 if retries > 0:
# -> 1447     return await self._retry_request(
#    1448         options,
#    1449         cast_to,
#    1450         retries,
#    1451         stream=stream,
#    1452         stream_cls=stream_cls,
#    1453         response_headers=None,
#    1454     )
#    1456 log.debug("Raising connection error")
#    1457 raise APIConnectionError(request=request) from err
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1516, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1512 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1514 await anyio.sleep(timeout)
# -> 1516 return await self._request(
#    1517     options=options,
#    1518     cast_to=cast_to,
#    1519     remaining_retries=remaining,
#    1520     stream=stream,
#    1521     stream_cls=stream_cls,
#    1522 )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1447, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1444 log.debug("Encountered Exception", exc_info=True)
#    1446 if retries > 0:
# -> 1447     return await self._retry_request(
#    1448         options,
#    1449         cast_to,
#    1450         retries,
#    1451         stream=stream,
#    1452         stream_cls=stream_cls,
#    1453         response_headers=None,
#    1454     )
#    1456 log.debug("Raising connection error")
#    1457 raise APIConnectionError(request=request) from err
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1516, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1512 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1514 await anyio.sleep(timeout)
# -> 1516 return await self._request(
#    1517     options=options,
#    1518     cast_to=cast_to,
#    1519     remaining_retries=remaining,
#    1520     stream=stream,
#    1521     stream_cls=stream_cls,
#    1522 )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1447, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1444 log.debug("Encountered Exception", exc_info=True)
#    1446 if retries > 0:
# -> 1447     return await self._retry_request(
#    1448         options,
#    1449         cast_to,
#    1450         retries,
#    1451         stream=stream,
#    1452         stream_cls=stream_cls,
#    1453         response_headers=None,
#    1454     )
#    1456 log.debug("Raising connection error")
#    1457 raise APIConnectionError(request=request) from err
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1516, in AsyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1512 log.info("Retrying request to %s in %f seconds", options.url, timeout)
#    1514 await anyio.sleep(timeout)
# -> 1516 return await self._request(
#    1517     options=options,
#    1518     cast_to=cast_to,
#    1519     remaining_retries=remaining,
#    1520     stream=stream,
#    1521     stream_cls=stream_cls,
#    1522 )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1457, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1447         return await self._retry_request(
#    1448             options,
#    1449             cast_to,
#    (...)
#    1453             response_headers=None,
#    1454         )
#    1456     log.debug("Raising connection error")
# -> 1457     raise APIConnectionError(request=request) from err
#    1459 log.debug(
#    1460     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#    1461 )
#    1463 try:
#
# APIConnectionError: Connection error.

# %%
# Chat with an intelligent assistant in your terminal
from openai import OpenAI

# Point to the local server
client = OpenAI(base_url="http://localhost:1234/v1", api_key="not-needed")

history = [
    {"role": "system", "content": "You are an intelligent assistant. You always provide well-reasoned answers that are both correct and helpful."},
    {"role": "user", "content": "Hello, introduce yourself to someone opening this program for the first time. Be concise."},
]

while True:
    completion = client.chat.completions.create(
        model="local-model", # this field is currently unused
        messages=history,
        temperature=0.7,
        stream=True,
    )

    new_message = {"role": "assistant", "content": ""}
    
    for chunk in completion:
        if chunk.choices[0].delta.content:
            print(chunk.choices[0].delta.content, end="", flush=True)
            new_message["content"] += chunk.choices[0].delta.content

    history.append(new_message)
    
    # Uncomment to see chat history
    # import json
    # gray_color = "\033[90m"
    # reset_color = "\033[0m"
    # print(f"{gray_color}\n{'-'*20} History dump {'-'*20}\n")
    # print(json.dumps(history, indent=2))
    # print(f"\n{'-'*55}\n{reset_color}")

    print()
    history.append({"role": "user", "content": input("> ")})
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      98         self._connect_failed = True
# ---> 99         raise exc
#     100 elif not self._connection.is_available():
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 try:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_backends/sync.py:205, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
# --> 205 with map_exceptions(exc_map):
#     206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:885, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     884 try:
# --> 885     response = self._client.send(
#     886         request,
#     887         stream=stream or self._should_stream_response_body(request=request),
#     888         **kwargs,
#     889     )
#     890 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      98         self._connect_failed = True
# ---> 99         raise exc
#     100 elif not self._connection.is_available():
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 try:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_backends/sync.py:205, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
# --> 205 with map_exceptions(exc_map):
#     206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:885, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     884 try:
# --> 885     response = self._client.send(
#     886         request,
#     887         stream=stream or self._should_stream_response_body(request=request),
#     888         **kwargs,
#     889     )
#     890 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:10, in map_exceptions(map)
#       9 try:
# ---> 10     yield
#      11 except Exception as exc:  # noqa: PIE786
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_backends/sync.py:206, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     205 with map_exceptions(exc_map):
# --> 206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#     211     for option in socket_options:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     850 if not all_errors:
# --> 851     raise exceptions[0]
#     852 raise ExceptionGroup("create_connection failed", exceptions)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:67, in map_httpcore_exceptions()
#      66 try:
# ---> 67     yield
#      68 except Exception as exc:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:231, in HTTPTransport.handle_request(self, request)
#     230 with map_httpcore_exceptions():
# --> 231     resp = self._pool.handle_request(req)
#     233 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:268, in ConnectionPool.handle_request(self, request)
#     267         self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:251, in ConnectionPool.handle_request(self, request)
#     250 try:
# --> 251     response = connection.handle_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:99, in HTTPConnection.handle_request(self, request)
#      98         self._connect_failed = True
# ---> 99         raise exc
#     100 elif not self._connection.is_available():
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:76, in HTTPConnection.handle_request(self, request)
#      75 try:
# ---> 76     stream = self._connect(request)
#      78     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_backends/sync.py:205, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     200 exc_map: ExceptionMapping = {
#     201     socket.timeout: ConnectTimeout,
#     202     OSError: ConnectError,
#     203 }
# --> 205 with map_exceptions(exc_map):
#     206     sock = socket.create_connection(
#     207         address,
#     208         timeout,
#     209         source_address=source_address,
#     210     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:885, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     884 try:
# --> 885     response = self._client.send(
#     886         request,
#     887         stream=stream or self._should_stream_response_body(request=request),
#     888         **kwargs,
#     889     )
#     890 except httpx.TimeoutException as err:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:915, in Client.send(self, request, stream, auth, follow_redirects)
#     913 auth = self._build_request_auth(request, auth)
# --> 915 response = self._send_handling_auth(
#     916     request,
#     917     auth=auth,
#     918     follow_redirects=follow_redirects,
#     919     history=[],
#     920 )
#     921 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:943, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     942 while True:
# --> 943     response = self._send_handling_redirects(
#     944         request,
#     945         follow_redirects=follow_redirects,
#     946         history=history,
#     947     )
#     948     try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:980, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     978     hook(request)
# --> 980 response = self._send_single_request(request)
#     981 try:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_client.py:1016, in Client._send_single_request(self, request)
#    1015 with request_context(request=request):
# -> 1016     response = transport.handle_request(request)
#    1018 assert isinstance(response.stream, SyncByteStream)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:230, in HTTPTransport.handle_request(self, request)
#     218 req = httpcore.Request(
#     219     method=request.method,
#     220     url=httpcore.URL(
#    (...)
#     228     extensions=request.extensions,
#     229 )
# --> 230 with map_httpcore_exceptions():
#     231     resp = self._pool.handle_request(req)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/httpx/_transports/default.py:84, in map_httpcore_exceptions()
#      83 message = str(exc)
# ---> 84 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[9], line 13
#       7 history = [
#       8     {"role": "system", "content": "You are an intelligent assistant. You always provide well-reasoned answers that are both correct and helpful."},
#       9     {"role": "user", "content": "Hello, introduce yourself to someone opening this program for the first time. Be concise."},
#      10 ]
#      12 while True:
# ---> 13     completion = client.chat.completions.create(
#      14         model="local-model", # this field is currently unused
#      15         messages=history,
#      16         temperature=0.7,
#      17         stream=True,
#      18     )
#      20     new_message = {"role": "assistant", "content": ""}
#      22     for chunk in completion:
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_utils/_utils.py:271, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     269             msg = f"Missing required argument: {quote(missing[0])}"
#     270     raise TypeError(msg)
# --> 271 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/resources/chat/completions.py:648, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     599 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     600 def create(
#     601     self,
#    (...)
#     646     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     647 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
# --> 648     return self._post(
#     649         "/chat/completions",
#     650         body=maybe_transform(
#     651             {
#     652                 "messages": messages,
#     653                 "model": model,
#     654                 "frequency_penalty": frequency_penalty,
#     655                 "function_call": function_call,
#     656                 "functions": functions,
#     657                 "logit_bias": logit_bias,
#     658                 "logprobs": logprobs,
#     659                 "max_tokens": max_tokens,
#     660                 "n": n,
#     661                 "presence_penalty": presence_penalty,
#     662                 "response_format": response_format,
#     663                 "seed": seed,
#     664                 "stop": stop,
#     665                 "stream": stream,
#     666                 "temperature": temperature,
#     667                 "tool_choice": tool_choice,
#     668                 "tools": tools,
#     669                 "top_logprobs": top_logprobs,
#     670                 "top_p": top_p,
#     671                 "user": user,
#     672             },
#     673             completion_create_params.CompletionCreateParams,
#     674         ),
#     675         options=make_request_options(
#     676             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     677         ),
#     678         cast_to=ChatCompletion,
#     679         stream=stream or False,
#     680         stream_cls=Stream[ChatCompletionChunk],
#     681     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:1167, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1153 def post(
#    1154     self,
#    1155     path: str,
#    (...)
#    1162     stream_cls: type[_StreamT] | None = None,
#    1163 ) -> ResponseT | _StreamT:
#    1164     opts = FinalRequestOptions.construct(
#    1165         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1166     )
# -> 1167     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:856, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     847 def request(
#     848     self,
#     849     cast_to: Type[ResponseT],
#    (...)
#     854     stream_cls: type[_StreamT] | None = None,
#     855 ) -> ResponseT | _StreamT:
# --> 856     return self._request(
#     857         cast_to=cast_to,
#     858         options=options,
#     859         stream=stream,
#     860         stream_cls=stream_cls,
#     861         remaining_retries=remaining_retries,
#     862     )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:909, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     906 log.debug("Encountered Exception", exc_info=True)
#     908 if retries > 0:
# --> 909     return self._retry_request(
#     910         options,
#     911         cast_to,
#     912         retries,
#     913         stream=stream,
#     914         stream_cls=stream_cls,
#     915         response_headers=None,
#     916     )
#     918 log.debug("Raising connection error")
#     919 raise APIConnectionError(request=request) from err
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:980, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     976 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     977 # different thread if necessary.
#     978 time.sleep(timeout)
# --> 980 return self._request(
#     981     options=options,
#     982     cast_to=cast_to,
#     983     remaining_retries=remaining,
#     984     stream=stream,
#     985     stream_cls=stream_cls,
#     986 )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:909, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     906 log.debug("Encountered Exception", exc_info=True)
#     908 if retries > 0:
# --> 909     return self._retry_request(
#     910         options,
#     911         cast_to,
#     912         retries,
#     913         stream=stream,
#     914         stream_cls=stream_cls,
#     915         response_headers=None,
#     916     )
#     918 log.debug("Raising connection error")
#     919 raise APIConnectionError(request=request) from err
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:980, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#     976 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#     977 # different thread if necessary.
#     978 time.sleep(timeout)
# --> 980 return self._request(
#     981     options=options,
#     982     cast_to=cast_to,
#     983     remaining_retries=remaining,
#     984     stream=stream,
#     985     stream_cls=stream_cls,
#     986 )
#
# File ~/anaconda3/envs/cairo-llm/lib/python3.11/site-packages/openai/_base_client.py:919, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     909         return self._retry_request(
#     910             options,
#     911             cast_to,
#    (...)
#     915             response_headers=None,
#     916         )
#     918     log.debug("Raising connection error")
# --> 919     raise APIConnectionError(request=request) from err
#     921 log.debug(
#     922     'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#     923 )
#     925 try:
#
# APIConnectionError: Connection error.
